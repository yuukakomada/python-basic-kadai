# %%
class Human:
    def __init__(self):
      self.name = ""
      self.age = 0

    def set_name(self,name,age):
      self.name = name
      self.age = age

    def get_name(self,name,age):
      print(self.name)
      print(self.age)

human = Human()

human.set_name("太郎",25)
human.get_name("太郎",25)
# Out:
# 太郎
# 25
